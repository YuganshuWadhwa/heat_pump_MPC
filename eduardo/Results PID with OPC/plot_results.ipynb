# %%
import pandas as pd
import plotly.graph_objects as go
from plotly.subplots import make_subplots

# %%
df = pd.read_csv("T_9_Unisim_PID.csv")

data = pd.DataFrame(df)


# Create a figure with secondary y-axis
fig = make_subplots(specs=[[{"secondary_y": True}]])

# Add traces for I_L1real
fig.add_trace(
    go.Scatter(x=data['Timestamp'], y=data['TC Compressor - PV'], mode='lines', name='TC Compressor - PV', line=dict(color='#d62728')),
    secondary_y=False,
)

# Add traces for U_L1real
fig.add_trace(
    go.Scatter(x=data['Timestamp'], y=data['TC Compressor - OP'], mode='lines', name='TC Compressor - OP', line=dict(color='#1f77b4')),
    secondary_y=True,
)

# Update layout
fig.update_layout(
    title='Unisim Advanced PI  -  PV vs OP',
    xaxis_title='Timestamp',
    legend_title='Signals'
)

# Set y-axes titles
fig.update_yaxes(title_text="TC Compressor - PV", secondary_y=False)
fig.update_yaxes(title_text="TC Compressor - OP", secondary_y=True)

# Show figure
fig.show()

# %%
df = pd.read_csv("T_9_Simulink_PID.csv")

data = pd.DataFrame(df)


# Create a figure with secondary y-axis
fig = make_subplots(specs=[[{"secondary_y": True}]])

# Add traces for I_L1real
fig.add_trace(
    go.Scatter(x=data['Timestamp'], y=data['TC Compressor - PV'], mode='lines', name='TC Compressor - PV', line=dict(color='#d62728')),
    secondary_y=False,
)

# Add traces for U_L1real
fig.add_trace(
    go.Scatter(x=data['Timestamp'], y=data['TC Compressor - OP'], mode='lines', name='TC Compressor - OP', line=dict(color='#1f77b4')),
    secondary_y=True,
)

# Update layout
fig.update_layout(
    title='Simulink Advanced PI  -  PV vs OP',
    xaxis_title='Timestamp',
    legend_title='Signals'
)

# Set y-axes titles
fig.update_yaxes(title_text="TC Compressor - PV", secondary_y=False)
fig.update_yaxes(title_text="TC Compressor - OP", secondary_y=True)

# Show figure
fig.show()

# %%
df = pd.read_csv("T_9_Unisim_PID_70perc.csv")

data = pd.DataFrame(df)


# Create a figure with secondary y-axis
fig = make_subplots(specs=[[{"secondary_y": True}]])

# Add traces for I_L1real
fig.add_trace(
    go.Scatter(x=data['Timestamp'], y=data['TC Compressor - PV'], mode='lines', name='TC Compressor - PV', line=dict(color='#d62728')),
    secondary_y=False,
)

# Add traces for U_L1real
fig.add_trace(
    go.Scatter(x=data['Timestamp'], y=data['TC Compressor - OP'], mode='lines', name='TC Compressor - OP', line=dict(color='#1f77b4')),
    secondary_y=True,
)

# Update layout
fig.update_layout(
    title='Unisim Advanced PI  -  PV vs OP',
    xaxis_title='Timestamp',
    legend_title='Signals'
)

# Set y-axes titles
fig.update_yaxes(title_text="TC Compressor - PV", secondary_y=False)
fig.update_yaxes(title_text="TC Compressor - OP", secondary_y=True)

# Show figure
fig.show()

# %%
df = pd.read_csv("T_9_Simulink_PID_70perc.csv")

data = pd.DataFrame(df)


# Create a figure with secondary y-axis
fig = make_subplots(specs=[[{"secondary_y": True}]])

# Add traces for I_L1real
fig.add_trace(
    go.Scatter(x=data['Timestamp'], y=data['TC Compressor - PV'], mode='lines', name='TC Compressor - PV', line=dict(color='#d62728')),
    secondary_y=False,
)

# Add traces for U_L1real
fig.add_trace(
    go.Scatter(x=data['Timestamp'], y=data['TC Compressor - OP'], mode='lines', name='TC Compressor - OP', line=dict(color='#1f77b4')),
    secondary_y=True,
)

# Update layout
fig.update_layout(
    title='Unisim Advanced PI  -  PV vs OP',
    xaxis_title='Timestamp',
    legend_title='Signals'
)

# Set y-axes titles
fig.update_yaxes(title_text="TC Compressor - PV", secondary_y=False)
fig.update_yaxes(title_text="TC Compressor - OP", secondary_y=True)

# Show figure
fig.show()

# %%
df = pd.read_csv("T_9_Unisim_PID_65perc.csv")

data = pd.DataFrame(df)


# Create a figure with secondary y-axis
fig = make_subplots(specs=[[{"secondary_y": True}]])

# Add traces for I_L1real
fig.add_trace(
    go.Scatter(x=data['Timestamp'], y=data['TC Compressor - PV'], mode='lines', name='TC Compressor - PV', line=dict(color='#d62728')),
    secondary_y=False,
)

# Add traces for U_L1real
fig.add_trace(
    go.Scatter(x=data['Timestamp'], y=data['TC Compressor - OP'], mode='lines', name='TC Compressor - OP', line=dict(color='#1f77b4')),
    secondary_y=True,
)

# Update layout
fig.update_layout(
    title='Unisim Advanced PI  -  PV vs OP',
    xaxis_title='Timestamp',
    legend_title='Signals'
)

# Set y-axes titles
fig.update_yaxes(title_text="TC Compressor - PV", secondary_y=False)
fig.update_yaxes(title_text="TC Compressor - OP", secondary_y=True)

# Show figure
fig.show()

# %%
df = pd.read_csv("T_9_Simulink_PID_65perc.csv")

data = pd.DataFrame(df)


# Create a figure with secondary y-axis
fig = make_subplots(specs=[[{"secondary_y": True}]])

# Add traces for I_L1real
fig.add_trace(
    go.Scatter(x=data['Timestamp'], y=data['TC Compressor - PV'], mode='lines', name='TC Compressor - PV', line=dict(color='#d62728')),
    secondary_y=False,
)

# Add traces for U_L1real
fig.add_trace(
    go.Scatter(x=data['Timestamp'], y=data['TC Compressor - OP'], mode='lines', name='TC Compressor - OP', line=dict(color='#1f77b4')),
    secondary_y=True,
)

# Update layout
fig.update_layout(
    title='Unisim Advanced PI  -  PV vs OP',
    xaxis_title='Timestamp',
    legend_title='Signals'
)

# Set y-axes titles
fig.update_yaxes(title_text="TC Compressor - PV", secondary_y=False)
fig.update_yaxes(title_text="TC Compressor - OP", secondary_y=True)

# Show figure
fig.show()

# %%
# Assuming you have already read your data
df = pd.read_csv("Sine_Unisim_PID.csv")
data = pd.DataFrame(df)

# Create a figure with secondary y-axis
fig = make_subplots(specs=[[{"secondary_y": True}]])

# Add traces for TC Compressor - PV
fig.add_trace(
    go.Scatter(x=data['Timestamp'], y=data['TC Compressor - PV'], mode='lines', name='TC Compressor - PV', line=dict(color='#d62728')),
    secondary_y=False,
)

# Add traces for TC Compressor - OP
fig.add_trace(
    go.Scatter(x=data['Timestamp'], y=data['TC Compressor - OP'], mode='lines', name='TC Compressor - OP', line=dict(color='#1f77b4')),
    secondary_y=True,
)

# Add traces for A10 - Temperature with custom y-axis
fig.add_trace(
    go.Scatter(x=data['Timestamp'], y=data['A10 - Temperature'], mode='lines', name='A10 - Temperature', line=dict(color='green')),
    secondary_y=True,
)

# Update layout
fig.update_layout(
    title='Unisim Advanced PI - PV vs OP and Tout',
    xaxis_title='Timestamp',
    legend_title='Signals',
    yaxis=dict(
        title='TC Compressor - PV',
        titlefont=dict(color='#d62728'),
        tickfont=dict(color='#d62728'),
    ),
    yaxis2=dict(
        title='TC Compressor - OP',
        titlefont=dict(color='#1f77b4'),
        tickfont=dict(color='#1f77b4'),
        anchor="free",
        overlaying="y",
        side="right",
        position=0.9
    ),
    yaxis3=dict(
        title='A10 - Temperature',
        titlefont=dict(color='green'),
        tickfont=dict(color='green'),
        anchor="x",
        overlaying="y",
        side="right",
        position=1
    ),
)

# Update the trace to use the third y-axis
fig.data[2].update(yaxis='y3')

# Show figure
fig.show()

# %%
# Assuming you have already read your data
df = pd.read_csv("Sine_simulink_PID.csv")
data = pd.DataFrame(df)

# Create a figure with secondary y-axis
fig = make_subplots(specs=[[{"secondary_y": True}]])

# Add traces for TC Compressor - PV
fig.add_trace(
    go.Scatter(x=data['Timestamp'], y=data['TC Compressor - PV'], mode='lines', name='TC Compressor - PV', line=dict(color='#d62728')),
    secondary_y=False,
)

# Add traces for TC Compressor - OP
fig.add_trace(
    go.Scatter(x=data['Timestamp'], y=data['TC Compressor - OP'], mode='lines', name='TC Compressor - OP', line=dict(color='#1f77b4')),
    secondary_y=True,
)

# Add traces for A10 - Temperature with custom y-axis
fig.add_trace(
    go.Scatter(x=data['Timestamp'], y=data['A10 - Temperature'], mode='lines', name='A10 - Temperature', line=dict(color='green')),
    secondary_y=True,
)

fig.add_trace(
    go.Scatter(x=data['Timestamp'], y=data['TC Compressor - SP'], mode='lines', name='TC Compressor - SP', line=dict(color='black')),
    secondary_y=True,
)


# Update layout
fig.update_layout(
    title='Simulink Advanced PI - PV vs OP and Tout',
    xaxis_title='Timestamp',
    legend_title='Signals',
    yaxis=dict(
        title='TC Compressor - PV',
        titlefont=dict(color='#d62728'),
        tickfont=dict(color='#d62728'),
    ),
    yaxis2=dict(
        title='TC Compressor - OP',
        titlefont=dict(color='#1f77b4'),
        tickfont=dict(color='#1f77b4'),
        anchor="free",
        overlaying="y",
        side="right",
        position=0.9
    ),
    yaxis3=dict(
        title='A10 - Temperature',
        titlefont=dict(color='green'),
        tickfont=dict(color='green'),
        anchor="x",
        overlaying="y",
        side="right",
        position=1
    ),
    yaxis4=dict(
        title='TC Compressor - SP',
        titlefont=dict(color='black'),
        tickfont=dict(color='black'),
        anchor="x",
        overlaying="y",
        side="right",
        position=1
    ),
)

# Update the trace to use the third y-axis
fig.data[2].update(yaxis='y3')

# Show figure
fig.show()
